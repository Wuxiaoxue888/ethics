# %%
# Import
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import tensorflow as tf
from tensorflow import keras
import random

# %%
df = pd.read_csv("real_images.csv")

# %% [markdown]
# # Combined image

# %%
image = df.iloc[0].to_numpy().reshape((28, 28))
plt.imshow(image, cmap='Greys')
plt.show()

# %%
image = df.iloc[1].to_numpy().reshape((28, 28))
plt.imshow(image, cmap='Greys')
plt.show()

# %%
combined = np.concatenate([df.iloc[0].values[:392], df.iloc[1].values[392:]])
image = combined.reshape((28, 28))
plt.imshow(image, cmap='Greys')
plt.show()

# %% [markdown]
# # Average image

# %%
image = df[2:6].mean().to_numpy().reshape((28, 28))
plt.imshow(image, cmap='Greys')
plt.show()

# %% [markdown]
# # Visualize distance_to_center

# %%
black_image = np.ones(784)
IMAGE_CENTER = 13.5
i, j = np.random.randint(0, 28), np.random.randint(0, 28)
image = black_image.reshape((28,28))
for i in range(0,28):
    for j in range(0,28): 
        distance_to_center = np.sqrt((i - IMAGE_CENTER) ** 2 + (j - IMAGE_CENTER) ** 2)
        if distance_to_center > 13:
            image[i, j] = 0.0

plt.imshow(image.reshape((28,28)), cmap='Greys')
plt.show()

# %% [markdown]
# # Try mutate function

# %%
def _mutate_1(offspring):
    index = np.random.randint(4, 24) * 28 + np.random.randint(4, 24) # a random pixel somewhat in the middle of the image
    pixel_change = np.random.randint(-255, 255) / 255. # the amount the pixel value will change
    p = np.random.random() # probability of moving to a pixel to the left or right, (1-p) is up or down
    probabilities = [p, 1-p]
    directions = [random.choice([-1, 1]) * 1,random.choice([-1, 1]) * 28] # the directions are left/right (-1, 1) and up/down (-28, 28) 
    for _ in range(np.random.randint(6, 10)): # number of pixels to be updated
        pixel_change += random.choice([-1, 1]) * np.random.random() / 20 # the pixel change is a bit different for each pixel
        new_pixel_value = offspring[index] + pixel_change # the new pixel value
        if new_pixel_value > 0 and new_pixel_value < 1: # check that the new pixel value is between 0 and 1
            offspring[index] = new_pixel_value # change the value of the pixel
        direction = np.random.choice(directions, p=probabilities) # choose a direction (left/right or up/down)
        new_index = index + direction # index of the next pixel to be updated
        if new_index >= 0 and new_index < 784: # check that it is not out of bounds
            index = new_index
    return offspring

# %%
black_image = np.ones(784)
_mutate_1(black_image)
plt.imshow(black_image.reshape((28,28)), cmap='Greys')
plt.show()

# %% [markdown]
# # Try mutate function 2

# %%
fake_images = pd.DataFrame(np.load("generated_images.npy"))
fake_images.columns = fake_images.columns.astype(str)

# %%
IMAGE_CENTER = 13.5

def draw_line(x, y, image):
    """
        x and why are the coordinates of a random pixel
        The idea is to check surrounding pixels to find if to draw a line vertically or horizontally
        A line is drawn by turning the pixels on the line blacker, and the surrounding pixels whiter
    """
    vertical = image[max(0,x-1):x+2, y].mean()
    horizontal = image[x, max(0,y-1):y+2].mean()

    if horizontal > vertical:
        # Strengthen horizintal line
        image[max(0,x-1):x+2, y] += np.random.random()
        image[max(0,x-2):x+3, y] += np.random.random() / 2
        # Weaken horizontal lines next to it
        if np.random.random() < 0.5:
            image[max(0,x-1):x+2, max(0,y-1)] += np.random.random() / 2
            image[max(0,x-1):x+2, min(27,y+1)] -= np.random.random() / 2
        else:
            image[max(0,x-1):x+2, max(0,y-1)] -= np.random.random() / 2
            image[max(0,x-1):x+2, min(27,y+1)] += np.random.random() / 2
        # Clearly weaken horizontal lines 2 pixels away
        image[max(0,x-1):x+2, max(0,y-2)] -= np.random.random()
        image[max(0,x-1):x+2, min(27,y+2)] -= np.random.random()
    else:
        # Strengthen vertical line
        image[x, max(0,y-1):y+2] += np.random.random()
        image[x, max(0,y-2):y+3] += np.random.random() / 2
        # Weaken vertical lines next to it
        if np.random.random() < 0.5:
            image[max(0,x-1), max(0,y-1):y+2] += np.random.random() / 2
            image[min(27, x+1), max(0,y-1):y+2] -= np.random.random() / 2
        else:
            image[max(0,x-1), max(0,y-1):y+2] -= np.random.random() / 2
            image[min(27,x+1), max(0,y-1):y+2] += np.random.random() / 2
        # Clearly weaken vertical lines 2 pixels away
        image[max(0,x-2), max(0,y-1):y+2] -= np.random.random()
        image[min(27,x+2), max(0,y-1):y+2] -= np.random.random()

    # No pixel should have a value below 0 or above 1
    image[image < 0] = 0.0
    image[image > 1] = 1.0

def _mutate_2(offspring):
    offspring = offspring.reshape((28,28))
    x, y = np.random.randint(0, 28), np.random.randint(0, 28)
    distance_to_center = np.sqrt((x - IMAGE_CENTER) ** 2 + (y - IMAGE_CENTER) ** 2)

    # if pixel is near the edge turn every nearby pixel in a 3x3 area white
    if distance_to_center > 13:
        offspring[max(0,x-1):x+2, max(0,y-1):y+2] = 0.0
        return offspring

    # if pixel is almost white, turn it and surrounding almost white pixels fully white
    if offspring[x][y] < 0.4:
        x_size, y_size = np.random.randint(2, 5), np.random.randint(2, 5)
        part = offspring[x:x+x_size, y:y+y_size]
        part[part < 0.4] = 0.0
    else:
        # call strengten line, to turn pixels black
        draw_line(x, y, offspring)

# %%
fake_image = fake_images.iloc[np.random.randint(0, len(fake_images)-1)].to_numpy()
_mutate_2(fake_image)
for _ in range(10000): # mutate same image over and over
    _mutate_2(fake_image)
plt.imshow(fake_image.reshape((28,28)), cmap='Greys')
plt.show()

# %% [markdown]
# # Try mutate function 3

# %%
def _mutate_3(offspring):
    offspring = offspring.reshape((28,28))
    x, y = np.random.randint(-4, 28), np.random.randint(-4, 28)
    x_size, y_size = np.random.randint(1, 6), np.random.randint(1, 6)
    offspring[max(0, x): max(0, x+x_size), max(0, y): max(0, y+y_size)] = 0

# %%
black_image = np.ones(784)
_mutate_3(black_image)
plt.imshow(black_image.reshape((28,28)), cmap='Greys')
plt.show()

# %% [markdown]
# # Try all 3 mutate functions together

# %%
fake_image = fake_images.iloc[np.random.randint(0, len(fake_images)-1)].to_numpy() / 255
for _ in range(10000): # mutate same image over and over
    p = np.random.random()
    if p < 2/10:
        _mutate_1(fake_image)
    elif p < 8.8/10:
        _mutate_2(fake_image)
    else:
        _mutate_3(fake_image)
plt.imshow(fake_image.reshape((28,28)), cmap='Greys')
plt.show()

# %% [markdown]
# # Random real image

# %%
image = df.iloc[np.random.randint(0, len(df)-1)].to_numpy().reshape((28, 28))
plt.imshow(image, cmap='Greys')
plt.show()

# %% [markdown]
# # Try new crossover function

# %%
parent_1 = df.iloc[356].to_numpy()
parent_2 = df.iloc[976].to_numpy()

# %%
plt.imshow(parent_1.reshape((28, 28)), cmap='Greys')
plt.show()
plt.imshow(parent_2.reshape((28, 28)), cmap='Greys')
plt.show()

# %%
N_GENES = 784
def _crossover(parent_1, parent_2):
    parent_1 = parent_1.reshape((28, 28))
    parent_2 = parent_2.reshape((28, 28))

    best_vertical_split_value = -1
    best_vertical_split_index = 14
    best_horizontal_split_value = -1
    best_horizontal_split_index = 14
    for i in range(6, 22):
        vertical_split_value = np.abs(parent_1[:, i] - parent_2[:, i+1]).mean()
        if vertical_split_value > best_vertical_split_value:
            best_vertical_split_value = vertical_split_value
            best_vertical_split_index = i+1
        horizontal_split_value = np.abs(parent_1[i, :] - parent_2[i+1, :]).mean()
        if horizontal_split_value > best_horizontal_split_value:
            best_horizontal_split_value = horizontal_split_value
            best_horizontal_split_index = i+1
            
    if best_horizontal_split_value > best_vertical_split_value:
        offspring_a, offspring_b = parent_1.copy(), parent_2.copy()
        offspring_a[:best_horizontal_split_index, :] = parent_2[:best_horizontal_split_index, :]
        offspring_b[:best_horizontal_split_index, :] = parent_1[:best_horizontal_split_index, :]
    else:
        offspring_a, offspring_b = parent_1.copy(), parent_2.copy()
        offspring_a[:, :best_vertical_split_index] = parent_2[:, :best_vertical_split_index]
        offspring_b[:, :best_vertical_split_index] = parent_1[:, :best_vertical_split_index]
    
    return offspring_a, offspring_b

# %%
offspring_a, offspring_b = _crossover(parent_1, parent_2)
plt.imshow(offspring_a.reshape((28, 28)), cmap='Greys')
plt.show()
plt.imshow(offspring_b.reshape((28, 28)), cmap='Greys')
plt.show()
